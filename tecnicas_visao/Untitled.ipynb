# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pyzbar.pyzbar as pyzbar
import copy
image = cv2.imread('img/GOPR9984.JPG')[:,:,::-1]
qr_data = pyzbar.decode(image)
plt.imshow(image)
print(qr_data)
print(len(qr_data))
# Out:
# [Decoded(data=b't: pontual\nw: 4', type='QRCODE', rect=Rect(left=1407, top=211, width=228, height=218), polygon=[Point(x=1407, y=423), Point(x=1635, y=429), Point(x=1634, y=218), Point(x=1412, y=211)])]
# 1
