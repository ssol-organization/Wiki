# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('triangular_10.png')


h, w = img.shape[:2]
print(h, w)
partes = int(w/10)
print(partes)
quadrante1 = int(w*(0.1861)/2)
print(quadrante1)
for i in range(0, h):
    for j in range(0, w):
        if j > quadrante1:
            img[i][j] = 255,255,255
        """if j > w-(partes*10) and j <w-(partes*9):
            ...
        else:
            img[i][j] = 255,255,255"""
plt.imshow(img)
print((957)/93)

#primeiro e ultimo = 18.61%
#segundo e penultmo = 19.49%
#terceito e antipenultimo = 20.20%
#quarto e antiantipenultimo = 20.71%
#centro = 20.98%
# Out:
# 622 957
# 95
# 89
# 10.290322580645162
